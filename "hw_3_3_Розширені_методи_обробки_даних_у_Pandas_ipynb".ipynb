# %% [markdown]
# <a href="https://colab.research.google.com/github/TetianaDS/Python-For-DS/blob/main/%22hw_3_3_%D0%A0%D0%BE%D0%B7%D1%88%D0%B8%D1%80%D0%B5%D0%BD%D1%96_%D0%BC%D0%B5%D1%82%D0%BE%D0%B4%D0%B8_%D0%BE%D0%B1%D1%80%D0%BE%D0%B1%D0%BA%D0%B8_%D0%B4%D0%B0%D0%BD%D0%B8%D1%85_%D1%83_Pandas_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнє завдання до теми "Розширені методи обробки даних у Pandas"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd
df = pd.read_csv('drive/MyDrive/DS_course/data/supermarket_sales.csv')

# %% [markdown]
# 1. Відсортуйте дані за спаданням ціни товара ('Unit price') і виведіть 5 перших рядочків на екран.

# %%
df.sort_values(by='Unit price', ascending=False).head(5)
# Out:
#       Invoice ID Branch       City Customer type Gender         Product line  \
# 983  148-41-7930      C  Naypyitaw        Normal   Male    Health and beauty
# 122  219-22-9386      B   Mandalay        Member   Male    Sports and travel
# 930  641-62-7288      B   Mandalay        Normal   Male   Home and lifestyle
# 494  437-53-3084      B   Mandalay        Normal   Male  Fashion accessories
# 283  667-92-0055      A     Yangon        Member   Male    Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 983       99.96         7  34.986  734.706  1/23/2019  10:33         Cash
# 122       99.96         9  44.982  944.622   3/9/2019  17:26  Credit card
# 930       99.92         6  29.976  629.496  3/24/2019  13:33      Ewallet
# 494       99.89         2   9.989  209.769  2/26/2019  11:48      Ewallet
# 283       99.83         6  29.949  628.929   3/4/2019  15:02      Ewallet
#
#        cogs  gross margin percentage  gross income  Rating
# 983  699.72                 4.761905        34.986     6.1
# 122  899.64                 4.761905        44.982     4.2
# 930  599.52                 4.761905        29.976     7.1
# 494  199.78                 4.761905         9.989     7.1
# 283  598.98                 4.761905        29.949     8.5

# %% [markdown]
# 2. Знайдіть інвойс (рядок в даних) в категорії товарів `Electronic accessories`, в якому був куплений товар з найбільшою кількістю і найбільшою ціною. Виведіть цей рядок даних на екран.

# %%
filter = df[df['Product line'] == 'Electronic accessories']

# %%
print("Найвища ціна товару у замовленні")
max_price = filter['Unit price'].max()
filter.query("`Unit price` == @max_price")
# Out:
# Найвища ціна товару у замовленні
#       Invoice ID Branch      City Customer type  Gender  \
# 209  817-69-8206      B  Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 209  Electronic accessories       99.73         9  44.8785  942.4485
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 209  3/2/2019  19:42  Credit card  897.57                 4.761905
#
#      gross income  Rating
# 209       44.8785     6.5

# %%
print("Найбільша кількість товару у замовленні")
max_quantity = filter['Quantity'].max()
filter.query("`Quantity` == @max_quantity").sort_values(by='Unit price', ascending=False)
# Out:
# Найбільша кількість товару у замовленні
#       Invoice ID Branch       City Customer type  Gender  \
# 887  13:14      Ewallet  734.7                 4.761905        36.735     9.5
# 761  15:12  Credit card  721.3                 4.761905        36.065     4.2
# 828  18:27         Cash  649.5                 4.761905        32.475     5.2
# 737  14:26      Ewallet  587.6                 4.761905        29.380     9.0
# 838  15:01         Cash  558.7                 4.761905        27.935     5.8
# 853  11:58      Ewallet  527.9                 4.761905        26.395    10.0
# 458  13:58         Cash  465.7                 4.761905        23.285     7.6
# 674  10:22  Credit card  454.8                 4.761905        22.740     4.8
# 75   17:04  Credit card  416.5                 4.761905        20.825     5.4
# 290  17:37  Credit card  403.0                 4.761905        20.150     7.0
# 811  18:06  Credit card  402.6                 4.761905        20.130     5.0
# 481  12:12         Cash  328.0                 4.761905        16.400     6.2
# 649  16:44         Cash  247.4                 4.761905        12.370     7.1
# 532  19:20      Ewallet  229.5                 4.761905        11.475     8.2
# 872  11:51         Cash  214.3                 4.761905        10.715     6.2
# 752  12:30      Ewallet  174.2                 4.761905         8.710     7.0

# %%
filter.query("`Unit price` == @max_price & Quantity == @max_quantity")
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %% [markdown]
# 3.1. Створіть нову колонку в даних `Rating Category`, яка визначає категорію рейтингу (`Rating`): високий, середній чи низький за наступним правилом:
# - якщо рейтинг вищий або рівний 8 - то він високий (`High`)
# - якщо рейтинг від 6 до 8 не включаючи - то він середній (`Medium`)
# - інакше - низький (`Low`).

# %%
def rating(a):
    if a >=8:
        return 'High'
    elif a >=6 and a <8:
        return 'Medium'
    else:
        return 'Low'
df['Rating Category'] = df.Rating.apply(rating).astype('category')

# %% [markdown]
# 3.2. Виведіть, який відсоток даних становить кожне зі значень категорій рейтингу.

# %%
df['Rating Category'].value_counts(normalize=True)*100
# Out:
# Rating Category
# Medium    35.6
# High      32.9
# Low       31.5
# Name: proportion, dtype: float64

# %% [markdown]
# 4.1. Запустіть код нижче аби створити змінну `time`. Ця змінна містить час в форматі "година:хвилина". Напишіть функцію `get_hour`, яка буде зі змінної формату як `time` дістати лише години і конвертувати їх у тип `int`.
#
# Запустіть написану функцію на змінній `time` та перевірте правильність роботи функції.

# %%
time = '11:28'

# %%
def get_hour(x:str):
    value = x.split(':')[0]
    return int(value)

# %%
get_hour(time)
# Out:
# 11

# %% [markdown]
# 4.2. З допомогою функції `get_hour` і метода `DataFrame.apply()` створіть нову колонку `Hour` в нашому наборі даних, яка буде містити години здійснення покупки, обчислені на основі часу здійснення покупки `Time`.

# %%
df['Hour'] = df.Time.apply(get_hour)

# %% [markdown]
# 4.3. Виведіть кількість значень за кожною годиною покупки і дайте відповідь "О яких годинах найбільше здійснюють покупок покупці і чому на Ваш погляд саме о цих годинах? Чи це слогічно, що найбільше покупок саме в ці години?".

# %%
df['Hour'].value_counts().sort_values(ascending=False)
# Out:
# Hour
# 19    113
# 13    103
# 15    102
# 10    101
# 18     93
# 11     90
# 12     89
# 14     83
# 16     77
# 20     75
# 17     74
# Name: count, dtype: int64

# %% [markdown]
# Піковими годинами є 19, 13, 15 та 10 години:
#  - 13 та 15 - можна пояснити, що це час обідньої перерви й тому, більше покупців;
#  - 10 та 19 - час, коли покупці добираються на та з роботи відповідно.
#  Тому можна висунути гіпотезу, що цей магазин розташований неподалік зупинки транспорту

# %% [markdown]
# 5. Виведіть середнє значення чеку (`Total`) для покупок в містах, наявних в даних, за допомогою функції `groupby`.

# %%
df.groupby('City')['Total'].mean()
# Out:
# City
# Mandalay     319.872506
# Naypyitaw    337.099715
# Yangon       312.354031
# Name: Total, dtype: float64

# %% [markdown]
# 6. Виведіть кількість покупок, середнє, мінімальне та максимальне значення для загальної суми чеку (Total) в містах, наявних в даних, за допомогою функції groupby.
# Зробіть висновки з цих показників та дайте рекомендації для мережі супермаркетів.

# %%
df.groupby('City')['Total'].agg(['count', 'mean', 'min', 'max', 'sum'])
# Out:
#            count        mean      min      max          sum
# City
# Mandalay     332  319.872506  18.6375  1022.49  106197.6720
# Naypyitaw    328  337.099715  10.6785  1042.65  110568.7065
# Yangon       340  312.354031  12.6945  1039.29  106200.3705

# %% [markdown]
# Місто Naypyitaw має найвищий показник по середньому чеку й по загальній сумі виторгу. В той час як кількість чеків найменша.
# Міста Yangon та Mandalay на одному рівні по показнику загального виторгу. Та в Yangon - найбільша кількість замовлень.
# Рекомендації:
# -  Yangon - працювати над збільшенням середнього чеку(консультації продавців, допродаж на касі);
# -  Naypyitaw - потрібно збільшувати кількість замовлень(працювати з рекламою, проводити промо для залучення нових клієнтів та переведення їх в статус постійних)
# -  Mandalay - середні значення показників, лише мінімальний чек є найвищим по всіх містам, хоча середній чек на посередньому рівні. Тобто, потрібно працювати над збільшенням середнього чеку, аналогічно Yangon

# %% [markdown]
# 7. Ми внесли деякі зміни в наш набір даних, тож, давайте запишемо результат у файл. Запишіть оновлену версію даних у файл `supermarket_sales_enriched.csv`. Зверніть увагу, аби не записати нічого зайвого, наприклад, індекси рядків нам в файлі не потрібні, оскільки вони стандартні.

# %%
df.to_csv('drive/MyDrive/DS_course/data/supermarket_sales_enriched.csv', index=False)

# %%
pd.read_csv('drive/MyDrive/DS_course/data/supermarket_sales_enriched.csv', nrows = 3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
#
#   Rating Category  Hour
# 0            High    13
# 1            High    10
# 2          Medium    13
