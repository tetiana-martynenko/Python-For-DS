# %% [markdown]
# <a href="https://colab.research.google.com/github/tetiana-martynenko/Python-For-DS/blob/main/HT_6_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завдання 1

# %% [markdown]
# В урні знаходиться 15 білих, 5 червоних і 10 чорних куль. Випадковим чином витягується 1 куля, знайти ймовірність того, що вона буде: а) білою, б) червоною, в) чорною.

# %% [markdown]
# Для вирішення задачі використовуємо класичне визначення (Лапласа).
# Ймовірність випадкової події A дорівнює відношенню числа m елементарних наслідків, які сприяють появі події A, до загального числа n усіх рівноможливих та єдиноможливих і несумісних елементарних наслідків.
#
# р(А)=𝑚 / 𝑛

# %% [markdown]
# Спочатку знаходимо  n - загальну к-ть куль, щоб визначити к-ть можливих варіацій.
#
# n = 15 + 10 + 5 = 30 (куль) - всього куль в урні
#
# Нехай P(A) - ймовірність витягнути кулю.
#
# Тоді:
#
# P(А) = 15 / 30 = 1 / 2 - ймовірність, що буде витягнена біла куля
#
# P(B) = 5 / 30 = 1 / 6 - ймовірність, що буде витягнена червона куля
#
# P(А) = 10 / 30 = 1 / 3 - ймовірність, що буде витягнена чорна куля

# %% [markdown]
# # Завдання 2

# %% [markdown]
# В магазин надійшло 30 холодильників, п'ять з яких мають заводський дефект. Випадковим чином обирають один холодильник. Яка ймовірність того, що він буде без дефекту?

# %% [markdown]
# У даному випадку вирішуємо задачу аналогічно Задачі 1.
# Відомо, що n = 30, так як всього холодильників 30.
#
# Можна піти одним шляхом - знайти к-ть без дефекту (30 - 5 = 25 холодильників).
# Звідси знайти P(A) = 25 / 30 = 5 / 6 (ймовірність того, що оберуть холодильник без дефекту.
#
# Або, так як ми знаємо, що може бути дві ситуації: або холодильник справний, або ні.
# Тобто, знаючи, що 5 холодильників з дефектом, їхня ймовірність P(B) = 5 / 30 = 1 / 6 .
#
# З теореми відомо, що так як вибір холодильника без дефекту - це доповнення множини холодильників з дефектом й їхня ймовірність P(B) = 1 - P(A)
#
# Звідси, P(B) = 1 - (5 / 30) = 5 / 6
#
# Отже, ймовірність, що холодильник буде без дефекту складає 5/6.

# %% [markdown]
# # Завдання 3

# %% [markdown]
# Набираючи номер телефону, абонент забув дві останні цифри, але пам'ятає, що одна з них — нуль, а інша — непарна. Знайти ймовірність того, що він набере правильний номер.

# %% [markdown]
# Спочатку визначаємо n - загально можливу к-ть комбінацій цифр.
#
# Знаючи, що одна з них, то інша може бути одна з 5 цифр (так як вона має бути непарна)
# Але також вони можуть бути в 2 варіаціях: або 0 спочатку, або навпаки.
# Відповідно, n = 2 * 5 = 10
#
# Набір номеру - одна подія.
# P(A) = 1 / 10 - ймовірність, що абонент набере правильний номер.

# %% [markdown]
# # Завдання 4

# %% [markdown]
# 4. Знайти ймовірність того, що при кидку двох гральних кубиків добуток чисел на них:
#
#     а) дорівнюватиме семи;
#     б) буде не меншим за 20;
#     в) буде парним.

# %% [markdown]
# Спочатку визначаємо n - загально можливу к-ть комбінацій цифр.
#
# У кожного кубика по 6 граней, кубика 2.
# Відповідно, n = 6 * 6 = 36 випадків.
#
# а) щоб добуток дорівнював 7, необхідно, щоб один із множників був 7.
# Так як на кубику 6 граней й немає цифри 7. Тому таких подій буде 0.
# Отже, ймовірність, що при кидку двох гральних кубиків добуток чисел на них дорівнюватиме семи складає 0 / 36 = 0.
#
# б)визначаємо к-ть можливість випадків, що добуток буде не меншим 20
# 4 * 5 = 20
# 5 * 4 = 20
# 4 * 6 = 24
# 6 * 4 = 24
# 5 * 5 = 25
# 5 * 6 = 30
# 6 * 5 = 30
# 6 * 6 = 36
# Всього 8 варіацій.
# Звідси ймовірність настання даної подій складає 8 / 36 = 2 / 9.
#
# в) визначаємо к-ть можливість випадків, що добуток буде парним, тобто один із кубиків має бути з парним значенням.
# Тобто, або на одному кубику має бути одне з 3 чисел(2, 4, 6), а на іншому будь-яке(1, 2, 3, 4, 5, 6), або навпаки. Так як можуть випасти однакові цифри на двох кубиках (тобто 2 * 2), таких випадків з парними числами може бути 9.  Й це є перетином двох множин й ми маємо відняти 9 від загального добутку
# Тоді, к-ть таких випадків дорівнює 3 * 6 * 2 - 9 = 27.
#
# Отже, 27 / 36 = 3 / 4 ймовірність, що буде парний добуток.

# %% [markdown]
# # Завдання 5

# %% [markdown]
# Ймовірність того, що на тесті з біології учень О. правильно розв'яже більше 11 задач, дорівнює 0,67. Ймовірність того, що О. правильно розв'яже більше 10 задач, дорівнює 0,74. Знайдіть ймовірність того, що О. правильно розв'яже рівно 11 задач.

# %% [markdown]
# P(A) = 0.67 (тобто 12 і більше задач)
#
# P(B) = 0.74 (тобто 11 та більше задач)
#
# P(C) = 0.74 - 0.67 = 0.07
#
# Так як у даному випадку подія С - буде різнице. подій В і A називається подія, яка полягає у тому, що настає подія B , але не настає подія A.
