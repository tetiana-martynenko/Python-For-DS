# %% [markdown]
# <a href="https://colab.research.google.com/github/TetianaDS/Python-For-DS/blob/main/%22hw_3_4_apply%2C_groupby%2C_pivot_table_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/DS_course/data/supermarket_sales.csv')

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
profit_branch = df.groupby('Branch')['gross income'].sum().astype(int)
profit_branch
# Out:
# Branch
# A    5057
# B    5057
# C    5265
# Name: gross income, dtype: int64

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
top_profit_city = df.groupby('City')['gross income'].sum().astype(int).idxmax()

# %%
print(f'Філія з найвищим прибутком знаходиться у місті {top_profit_city}.')
# Out:
# Філія з найвищим прибутком знаходиться у місті Naypyitaw.

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = df.pivot_table(index= 'Branch', columns= 'Product line', values= 'Invoice ID', aggfunc="count")
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category["Electronic accessories"].idxmax()
# Out:
# 'A'

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# Гіпотеза 1
# Перевірити чи схожий розподіл по кількості замовлень чоловіків/жінок по кожному місту

# %%
distribution_by_city_count = df.pivot_table(index= ['City', 'Gender'],  values= 'Invoice ID', aggfunc="count")

# %%
distribution_by_city = df.pivot_table(index= ['City', 'Gender'],  values= 'Invoice ID', aggfunc="count")
distribution_by_city.sort_values(by=['City','Invoice ID'], ascending=False)
# Out:
#                   Invoice ID
# City      Gender
# Yangon    Male           179
#           Female         161
# Naypyitaw Female         178
#           Male           150
# Mandalay  Male           170
#           Female         162

# %% [markdown]
# Відповідь:
# у двох з трьох міст переважаюча доля клієнтів - чоловіки.
# Лише у місті Naypyitaw - це жінки. Й саме це місто має найвищий показник прибутковості (визначено попередньо).
# Звідси випливає наступна Гіпотеза 2

# %% [markdown]
# Гіпотеза 2
# Перевірити, чи по сумарній сумі замовлень у містах аналогічний розподіл по гендерній ознаці.

# %%
distribution_by_cogs = df.pivot_table(index= ['City', 'Gender'],  values= 'cogs', aggfunc="sum")
round(distribution_by_cogs.sort_values(by=['City','cogs'], ascending=False), 0)
# Out:
#                      cogs
# City      Gender
# Yangon    Female  50733.0
#           Male    50411.0
# Naypyitaw Female  58748.0
#           Male    46555.0
# Mandalay  Male    50733.0
#           Female  50408.0

# %% [markdown]
# Відповідь:
# Гіпотезу підтверджено, за винятком міста Yangon - у якому з незначним відхиленням, але сума замовлень у чоловіків вища.
# Та, водночас, окремо розглядаючи місто Naypyitaw - з найвищим рівнем прибутку, то можна дійти висновку, що жіноча аудиторія більш активна не лише по кількості замовлень, а й сумі.
# Тобто, у містах Yangon та Mandalay - необхідно покращити роботу з жіночою аудиторією.

# %% [markdown]
# Гіпотеза 3
# НЕобхідно перевірити, чи категорії, які приносять основу по сумі замовлень у місті Naypyitaw у жінок, не просідають у двох інших містах. Це дасть нам зрозуміти, над якими категоріями потрібно працювати з жіночою аудиторією у цих двох містах.

# %%
distribution_by_product["share, %"] = round(
    (distribution_by_product['Invoice ID'] /
     distribution_by_city['Invoice ID']) * 100, 2
)

distribution_by_product.sort_values(by=['City','Gender', 'Invoice ID'], ascending=False)
# Out:
#                                          Invoice ID  share, %
# City      Gender Product line
# Yangon    Male   Food and beverages              35     19.55
#                  Home and lifestyle              33     18.44
#                  Electronic accessories          32     17.88
#                  Sports and travel               30     16.76
#                  Health and beauty               26     14.53
#                  Fashion accessories             23     12.85
#           Female Home and lifestyle              32     19.88
#                  Sports and travel               29     18.01
#                  Electronic accessories          28     17.39
#                  Fashion accessories             28     17.39
#                  Food and beverages              23     14.29
#                  Health and beauty               21     13.04
# Naypyitaw Male   Fashion accessories             30     20.00
#                  Health and beauty               29     19.33
# ...

# %% [markdown]
# ---

# %% [markdown]
# Відповідь:
# Отже, визначено рекомендації для міста Yangon - розвивати категорію Food and beverages для жінок, для міста Mandalay - розподіл каьегорій по кількості замовлень схожий з Naypyitaw. Тому необхідно працювати зі збільшенням середнього чеку загалом.
